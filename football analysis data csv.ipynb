# %%
##soccer game analysis 4 chart
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

df = pd.read_csv(r'C:\Users\shah8\hello\soccer game analysis\s21-22.csv')

df.head()
# Out:
#   Div       Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/8/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/8/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/8/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/8/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/8/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# 1     1.93     2.10     1.79
# ...

# %%
##soccer game analysis last chart
df.tail()
# Out:
#     Div       Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 375  E0  22/5/2022  16:00  Crystal Palace   Man United     1     0   H     1
# 376  E0  22/5/2022  16:00       Leicester  Southampton     4     1   H     0
# 377  E0  22/5/2022  16:00       Liverpool       Wolves     3     1   H     1
# 378  E0  22/5/2022  16:00        Man City  Aston Villa     3     2   H     0
# 379  E0  22/5/2022  16:00         Norwich    Tottenham     0     5   A     0
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 375     0  ...     2.04  0.25      1.68      2.15   1.74   2.23     1.88
# 376     0  ...     2.63 -0.75      1.83      2.07   1.88   2.03     1.94
# 377     1  ...     3.28 -2.50      2.02      1.77   2.06   1.83     2.19
# 378     1  ...     3.36 -2.25      2.06      1.84   2.05   1.86     2.09
# 379     2  ...     2.40  1.50      1.95      1.95   1.96   1.94     2.16
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 375     2.25     1.74     2.16
# ...

# %%
len(df)
# Out:
# 380

# %%
df.dtypes
# Out:
# Div          object
# Date         object
# Time         object
# HomeTeam     object
# AwayTeam     object
#              ...
# PCAHA       float64
# MaxCAHH     float64
# MaxCAHA     float64
# AvgCAHH     float64
# AvgCAHA     float64
# Length: 106, dtype: object

# %%
##Full time home game (hometeam)
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\shah8\hello\soccer game analysis\s21-22.csv')

x = df['FTHG']
y = df['HomeTeam']
#FTHG = full time home team goal
plt.bar(x,y)
plt.show()

# %%
##full time home game (awayteam)
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\shah8\hello\soccer game analysis\s21-22.csv')

x = df['FTHG']
y = df['AwayTeam']
#FTHG = full time home team goal
plt.bar(x,y)
plt.show()

# %%
import numpy as np
import pandas as pd

df = pd.read_csv(r'C:\Users\shah8\hello\soccer game analysis\s21-22.csv')

x = df['FTHG']
y = df['AwayTeam']


# Function to plot
plt.scatter(x, y)
 
# Adding Title
plt.title("how many game win")
 
# Labeling the axes
plt.xlabel("HTR (half time result)")
plt.ylabel("Hometeam")
 
# function to show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data into a pandas DataFrame
df = pd.read_csv(r'C:\Users\shah8\hello\soccer game analysis\s21-22.csv')

x = df['HST']
y = df['AST']

# Function to plot
plt.scatter(x, y)

plt.title('Distribution of shots Scored in 21/22 PL')
plt.xlabel('HST(Hometeamshot)')
plt.ylabel('AST(Awayteamshot)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data into a pandas DataFrame
df = pd.read_csv(r'C:\Users\shah8\hello\soccer game analysis\s21-22.csv')

x1 = df['Time']
y1 = df['HF']

x2 = df['Time']
y2 = df['AF']

# First plot
plt.scatter(x1, y1)

plt.title('Distribution of  Team Fouls in 21/22 PL')
plt.xlabel('Time')
plt.ylabel('Team Fouls')

# Second plot
plt.scatter(x2, y2)

plt.title('Distribution of Away Team Fouls in 21/22 PL')
plt.xlabel('Time')
plt.ylabel('Team Fouls')

# Display the plots
plt.show()

# %%
##full time home game (awayteam)
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\shah8\hello\soccer game analysis\s21-22.csv')

x = df['BWD']
x2 = df['BWH']

plt.title('Betting odd data')
plt.plot(x)
plt.plot(x2)
plt.show()
